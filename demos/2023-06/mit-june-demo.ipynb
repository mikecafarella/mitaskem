# %% [markdown]
# # MIT (TA1): From Paper and Code to annotated extraction
#
# *[Step 3 -  M3: Data profiling API](#cellm3)
#
# *[Step 5 -  M1: MIT extraction pipeline demo](#cellm1)
#
# *[Step 6 -  M2: TA1 abstractions merge pipeline demo](#cellm2)

# %% [markdown]
# ## 0. Preprocessing

# %%
import ast, json, requests, os
from gpt_key import *
API_ROOT = "http://localhost:8000/"

# %% [markdown]
# #### We can run a local script to consolidate the "content" fields to get just the text of the paper:

# %% [markdown]
# ## 1. Extracting variables and annotating them from the text and the DKG

# %% [markdown]
# #### We extract variables from the paper alongside a list of possible definitions, and ground each of these variables to the MIRA DKG.

# %%
with open("../../demos/2023-07/text_ijerph-18-09027.txt", "r") as f:
        text = f.read()           
        dct_extract = {"text":text, "gpt_key":GPT_KEY}           
        json_str = requests.post(API_ROOT + "annotation/find_text_vars/", params=dct_extract).text

# %%
ast.literal_eval(json_str)
# Out:
# [{'type': 'variable',
#   'name': 'Maximum infection',
#   'id': 'v0',
#   'text_annotations': [' the spread of COVID-19 in the community'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 'Delay in compulsory mask wearing',
#   'id': 'v1',
#   'text_annotations': [' the impact of the delay in compulsory mask wearing on the spread of COVID-19 in the community'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 'SEIR-based compartmental models',
#   'id': 'v2',
#   'text_annotations': [' modiﬁed SEIR-based compart- mental modelsMaximum Infected Values'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 'Time Window',
#   'id': 'v3',
#   'text_annotations': [' approximately 80-100 days delay after the first infection is detected'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 'Delay Threshold',
#   'id': 'v4',
#   'text_annotations': [' about 100 days'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 'SEIR Model',
#   'id': 'v5',
#   'text_annotations': [' compartmental model used to simulate the spread of a pandemic'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 'SEIS Model',
#   'id': 'v6',
#   'text_annotations': [' compartmental model used to simulate the spread of a pandemic'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 'Mask Wearing',
#   'id': 'v7',
#   'text_annotations': [' compulsory mask wearing in public spacesNoneMaximum Infected Values'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 'SEIR',
#   'id': 'v8',
#   'text_annotations': [' lockdown measures',
#    ' Compartmentalized mathematical model used to model infectious diseases.'],
#   'dkg_annotations': [['geonames:5750162', 'Salem'],
#    ['geonames:5406567', 'Visalia']]},
#  {'type': 'variable',
#   'name': 'SEIRS',
#   'id': 'v9',
#   'text_annotations': [' effects of age-structure within the populationSEIR',
#    ' Susceptible-Exposed-Infected-Recovered-Susceptible model'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 'Compliance',
#   'id': 'v10',
#   'text_annotations': [' Level of adherence to a given policy'],
#   'dkg_annotations': [['apollosv:00000050', 'antiviral compliance'],
#    ['apollosv:00000024', 'vaccination compliance']]},
#  {'type': 'variable',
#   'name': 'Noncompliance',
#   'id': 'v11',
#   'text_annotations': [' Level of non-adherence to a given policy',
#    ' Level of noncompliance of the population.'],
#   'dkg_annotations': [['oae:0006383', 'diet noncompliance AE']]},
#  {'type': 'variable',
#   'name': 'Immunity',
#   'id': 'v12',
#   'text_annotations': [' Time-limited resistance to infection'],
#   'dkg_annotations': [['ido:0000621', 'acquired immunity to infectious agent'],
#    ['idomal:0000012', 'immunity']]},
#  {'type': 'variable',
#   'name': 'Macroscopic',
#   'id': 'v13',
#   'text_annotations': [' Viewpoint of the model from a large-scale perspectiveDelay of Mask Enforcement'],
#   'dkg_annotations': [['hp:0012587', 'Macroscopic hematuria'],
#    ['ncit:C119859', 'Macroscopic Findings Evaluator']]},
#  {'type': 'variable',
#   'name': 'Maximum Infection Value',
#   'id': 'v14',
#   'text_annotations': [' the highest number of infections predicted by the model'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 'Scenario 1',
#   'id': 'v15',
#   'text_annotations': [' complete compliance of the masking enforcement',
#    ' the first scenario studied, in which the effects of compulsory mask wearing are studied in isolation.'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 'Scenario 2',
#   'id': 'v16',
#   'text_annotations': [' gradual noncompliance of the masking enforcementNoneNoneMaximum Infected Values',
#    ' SEIR with full compliance'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 'NoneN',
#   'id': 'v17',
#   'text_annotations': [' Total population'],
#   'dkg_annotations': [['doid:0110973', 'Mononen-Karnes-Senac syndrome'],
#    ['doid:5914', 'nonencapsulated sclerosing carcinoma']]},
#  {'type': 'variable',
#   'name': 'S(t)',
#   'id': 'v18',
#   'text_annotations': [' Number of people susceptible on day t'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 'E(t)',
#   'id': 'v19',
#   'text_annotations': [' Number of people exposed on day t'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 'I(t)',
#   'id': 'v20',
#   'text_annotations': [' Number of people infected on day t'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 'R(t)',
#   'id': 'v21',
#   'text_annotations': [' Number of people recovered on day t'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 'D(t)',
#   'id': 'v22',
#   'text_annotations': [' Number of people dead on day t'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 'β',
#   'id': 'v23',
#   'text_annotations': [' Expected number of people an infected person infects per day'],
#   'dkg_annotations': [['geonames:702550', 'Lviv'],
#    ['geonames:3553478', 'Havana']]},
#  {'type': 'variable',
#   'name': 'γ',
#   'id': 'v24',
#   'text_annotations': [' Proportion of recovery per day', ' recovery rateδ'],
#   'dkg_annotations': [['geonames:3105976', 'Vigo'],
#    ['geonames:456172', 'Riga']]},
#  {'type': 'variable',
#   'name': 'δ',
#   'id': 'v25',
#   'text_annotations': [' Incubation period'],
#   'dkg_annotations': [['geonames:2797656', 'Gent'],
#    ['geonames:325363', 'Adana']]},
#  {'type': 'variable',
#   'name': 'α',
#   'id': 'v26',
#   'text_annotations': [' Fatality rate due to the infection',
#    ' Fatality rate'],
#   'dkg_annotations': [['geonames:298117', 'Van'],
#    ['geonames:2467454', 'Sfax']]},
#  {'type': 'variable',
#   'name': 'ρ',
#   'id': 'v27',
#   'text_annotations': [' Inverse of the average number of days for an infected person to die if he does not recoverSusceptible',
#    ' Average time for recovery from COVID-19'],
#   'dkg_annotations': [['geonames:2063523', 'Perth'],
#    ['geonames:2485926', 'Oran']]},
#  {'type': 'variable',
#   'name': 'Exposed',
#   'id': 'v28',
#   'text_annotations': [' Individuals who have been exposed to the disease, but are not yet infected.'],
#   'dkg_annotations': [['ncit:C71551', 'Exposed Population'],
#    ['cemo:exposed_contacts', 'exposed contacts']]},
#  {'type': 'variable',
#   'name': 'Infected',
#   'id': 'v29',
#   'text_annotations': [' Individuals who are currently infected with the disease.'],
#   'dkg_annotations': [['ido:0000511', 'infected population'],
#    ['efo:0001460', 'uninfected']]},
#  {'type': 'variable',
#   'name': 'Recovered',
#   'id': 'v30',
#   'text_annotations': [' Individuals who have recovered from the disease.'],
#   'dkg_annotations': [['ncit:C173781', 'Recovered Rate'],
#    ['apollosv:00000302', 'recovered organism']]},
#  {'type': 'variable',
#   'name': 'Death',
#   'id': 'v31',
#   'text_annotations': [' Individuals who have died from the disease.'],
#   'dkg_annotations': [['ncit:C28554', 'Dead'],
#    ['ncit:C168970', 'Death due to Disease Progression']]},
#  {'type': 'variable',
#   'name': '\x01',
#   'id': 'v32',
#   'text_annotations': [' Rate at which a recovered person becomes susceptible again.κ'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 'βs',
#   'id': 'v33',
#   'text_annotations': [' infection before the start of the outbreak',
#    ' infection rate'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 'βc',
#   'id': 'v34',
#   'text_annotations': [' infection after full compliance masking enforcement',
#    ' quenching of the infection rate due to enforcement of the compulsory mask wearing'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 'm(t)',
#   'id': 'v35',
#   'text_annotations': [' modified logistic function'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 't0',
#   'id': 'v36',
#   'text_annotations': [' number of days after the first case where masking wearing is enforcedm(t)',
#    ' period of time before onset of noncompliance'],
#   'dkg_annotations': [['vo:0011346', 'DeltaFTT0918'],
#    ['vo:0005085', 'VAT00002']]},
#  {'type': 'variable',
#   'name': 'βnc',
#   'id': 'v37',
#   'text_annotations': [' noncompliance of universal masking',
#    ' Rate of infection.R0'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 'k1',
#   'id': 'v38',
#   'text_annotations': [' arbitrary constant'],
#   'dkg_annotations': [['chebi:189661', 'RapaLink-1'],
#    ['pr:000009406', 'kallikrein-1']]},
#  {'type': 'variable',
#   'name': 'k2',
#   'id': 'v39',
#   'text_annotations': [' arbitrary constant'],
#   'dkg_annotations': [['geonames:1877030', 'Hŭngnam'],
#    ['pr:Q9UHD9', 'ubiquilin-2 (human)']]},
#  {'type': 'variable',
#   'name': 't1',
#   'id': 'v40',
#   'text_annotations': [' onset of noncomplianceβnc',
#    ' days after the first case'],
#   'dkg_annotations': [['vo:0011160', 'BT1'],
#    ['probonto:k0000082', 'Wishart1']]},
#  {'type': 'variable',
#   'name': 'NoneScenario 1',
#   'id': 'v41',
#   'text_annotations': [' complete compliance throughout the duration of mask enforcement'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 'Maximum Infected Value',
#   'id': 'v42',
#   'text_annotations': [' global maxima of the Infected compartment',
#    ' Maximum number of people infected.'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 'Number of Days',
#   'id': 'v43',
#   'text_annotations': [' number of days taken to reach the Maximum Infected Value'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 'Delay in Mask Enforcement',
#   'id': 'v44',
#   'text_annotations': [' delay in enforcing mask wearingMaximum infected value',
#    ' The amount of time before a mask enforcement policy is put into effect.'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 'Peak',
#   'id': 'v45',
#   'text_annotations': [' Day when the maximum infected value occurs.'],
#   'dkg_annotations': [['geonames:4752186', 'Chesapeake'],
#    ['hp:0002300', 'Mutism']]},
#  {'type': 'variable',
#   'name': 'Delay',
#   'id': 'v46',
#   'text_annotations': [' Length of time before public masking is enforced.'],
#   'dkg_annotations': [['doid:0111357', 'adermatoglyphia'],
#    ['doid:0111158', 'SADDAN']]},
#  {'type': 'variable',
#   'name': 'NoneMaximum Infected Value',
#   'id': 'v47',
#   'text_annotations': [' The maximum percentage of people infected by a virus.'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 'Scenario 3',
#   'id': 'v48',
#   'text_annotations': [' SEIRS with time-limited immunity',
#    ' SEIRS with time-limited immunity'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 'Transition Point',
#   'id': 'v49',
#   'text_annotations': [' the point at which the effectiveness of an intervention is greatly reduced.'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 'Maximum Infected Numbers',
#   'id': 'v50',
#   'text_annotations': [' Maximum number of people infected due to B117 variant'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 'Delay in public mask enforcement',
#   'id': 'v51',
#   'text_annotations': [' Delay in enforcing public mask wearingScenario 2'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 'Delay in mask enforcement',
#   'id': 'v52',
#   'text_annotations': [' amount of time before mask enforcement is implemented.NoneMaximum Infected Values'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 'Maximum Infection Rate',
#   'id': 'v53',
#   'text_annotations': [' The highest rate of infection that can be achieved without public masking.Maximum Infected Values'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 'Scenarios',
#   'id': 'v54',
#   'text_annotations': [' Three scenarios considered over two varied mathematical models.'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 'Time-limited Immunity',
#   'id': 'v55',
#   'text_annotations': [' Presence of time-limited immunity.'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 'Mask Enforcement',
#   'id': 'v56',
#   'text_annotations': [' States enforcing public masking.NoneSARS transmission'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 'COVID-19',
#   'id': 'v57',
#   'text_annotations': [' Big data analytics, new technology, and proactive testing',
#    ' COVID-19 cases'],
#   'dkg_annotations': [['ncit:C171133', 'COVID-19 Infection'],
#    ['doid:0080600', 'COVID-19']]},
#  {'type': 'variable',
#   'name': 'Face mask use',
#   'id': 'v58',
#   'text_annotations': [' potential for face mask use by the general public to curtail the COVID-19 pandemic'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 'NoneNoneSIR',
#   'id': 'v59',
#   'text_annotations': [' Susceptible, Infected, Recovered'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 'NoneSEIRS',
#   'id': 'v60',
#   'text_annotations': [' nonautonomous SEIRS model in epidemiology'],
#   'dkg_annotations': []},
#  {'type': 'variable',
#   'name': 'Mitigation Measures',
#   'id': 'v61',
#   'text_annotations': [' implementation of mitigation measuresNoneNoneNoneNone.'],
#   'dkg_annotations': []}]

# %% [markdown]
# ## 2. Adding annotations from dataset columns

# %% [markdown]
# #### Alongside the text, we might also have discovered a collection of datasets that we think might be relevant:

# %%
with open("../../resources/dataset/covid_confirmed_usafacts.csv") as f:
    dataset_1 = f.read()
    print(dataset_1[:150])
# Out:
# countyFIPS,County Name,State,StateFIPS,2020-01-22
# 0,"Statewide Unallocated","AL","01",0
# 1001,"Autauga County ","AL","01",0

# %%
with open("../../resources/dataset/covid_deaths_usafacts.csv") as f:
    dataset_2 = f.read()
    print(dataset_2[:150])
# Out:
# countyFIPS,County Name,State,StateFIPS,2020-01-22
# 0,"Statewide Unallocated","AL","01",0
# 1001,"Autauga County ","AL","01",0

# %% [markdown]
# #### Let's collect just the column names into a single file:

# %%
dir = "../../resources/dataset/"
with open(os.path.join(dir,"headers.txt"), "w+") as fw:
    for filename in os.listdir(dir):
        file = os.path.join(dir, filename)
        if os.path.isfile(file) and file.endswith(".csv"):
            fw.write("{}:\t{}".format(filename, open(file, "r").readline()))

# %%
with open(os.path.join(dir,"headers.txt")) as f:
    dataset_str = f.read()
    print(dataset_str[:419])
# Out:
# COVID-19_Reported_Patient_Impact_and_Hospital_Capacity_by_State_Archive_Repository.csv:	Update Date,Days Since Update,User,Rows,Row Change,Columns,Column Change,Metadata Published,Metadata Updates,Column Level Metadata,Column Level Metadata Updates,Archive Link
# StatewideCOVID-19CasesDeathsTests.csv:	date,area,area_type,population,cases,cumulative_cases,deaths,cumulative_deaths,total_tests,cumulative_total_tests,posi

# %% [markdown]
# #### Now we can call our `annotation/link_datasets_to_vars` endpoint to map variables discovered earlier to any matching dataset columns (GIGO warning here):

# %%
dct_cols = {"json_str":json_str, "dataset_str": dataset_str, "gpt_key":GPT_KEY}           
json_str = requests.post(API_ROOT + "annotation/link_datasets_to_vars/", params=dct_cols).text
json_str
# Out:
# '"OpenAI connection error: The server is overloaded or not ready yet."'

# %%
ast.literal_eval(json_str)
# Out:
# 'OpenAI connection error: The server is overloaded or not ready yet.'

# %% [markdown]
# ## 3. Annotate dataset and ground to the DKG
# <a id="cellm3"></a>

# %% [markdown]
# #### Let's collect column names from a csv file:

# %%
with open("../../resources/dataset/us-counties.csv", "r") as f:
    col_str = f.read()
print(col_str)
# Out:
# date,county,state,fips,cases,deaths
# 2020-01-21,Snohomish,Washington,53061,1,0
# 2020-01-22,Snohomish,Washington,53061,1,0
# 2020-01-23,Snohomish,Washington,53061,1,0
# 2020-01-24,Cook,Illinois,17031,1,0
# 2020-01-24,Snohomish,Washington,53061,1,0
# 2020-01-25,Orange,California,06059,1,0
# 2020-01-25,Cook,Illinois,17031,1,0

# %%
with open("../../resources/dataset/us-counties_doc.txt", "r") as f:
    col_doc = f.read()
print(col_doc)
# Out:
# The data is the product of dozens of journalists working across several time zones to monitor news conferences, analyze data releases and seek clarification from public officials on how they categorize cases.
#
# It is also a response to a fragmented American public health system in which overwhelmed public servants at the state, county and territorial level have sometimes struggled to report information accurately, consistently and speedily. On several occasions, officials have corrected information hours or days after first reporting it. At times, cases have disappeared from a local government database, or officials have moved a patient first identified in one state or county to another, often with no explanation. In those instances, which have become more common as the number of cases has grown, our team has made every effort to update the data to reflect the most current, accurate information while ensuring that every known case is counted.
#
# When the information is available, we count patients where they are being treated, not necessarily where they live.
#
# In most instances, the process of recording cases has been straightforward. But because of the patchwork of reporting methods for this data across more than 50 state and territorial governments and hundreds of local health departments, our journalists sometimes had to make difficult interpretations about how to count and record cases.
#
# For those reasons, our data will in some cases not exactly match with the information reported by states and counties. Those differences include these cases: When the federal government arranged flights to the United States for Americans exposed to the coronavirus in China and Japan, our team recorded those cases in the states where the patients subsequently were treated, even though local health departments generally did not. When a resident of Florida died in Los Angeles, we recorded her death as having occurred in California rather than Florida, though officials in Florida counted her case in their own records. And when officials in some states reported new cases without immediately identifying where the patients were being treated, we attempted to add information about their locations later, once it became available.
#
# "Probable" and “Confirmed Cases and Deaths
# Cases and deaths can be reported as either “confirmed” or “probable.” Our total cases and deaths include both. The number of cases includes all cases, including those who have since recovered or died.
#
# On April 5, 2020, the Council of State and Territorial Epidemiologists advised states to include both confirmed cases, based on confirmatory laboratory testing, and probable cases, based on specific criteria for testing, symptoms and exposure. The Centers for Disease Control adopted these definitions and national CDC data began including confirmed and probable cases on April 14, 2020.
#
# Some governments continue to report only confirmed cases, while others are reporting both confirmed and probable numbers. And there is also another set of governments that is reporting the two types of numbers combined without providing a way to separate the confirmed from the probable.
#
# The Geographic Exceptions section below has more details on specific areas. The methodology of individual states changes frequently.
#
# Confirmed Cases
# Confirmed cases are counts of individuals whose coronavirus infections were confirmed by a laboratory test and reported by a federal, state, territorial or local government agency. Only tests that detect viral RNA in a sample are considered confirmatory. These are often called molecular or RT-PCR tests.
#
# Probable Cases
# Probable cases count individuals who did not have a confirmed test but were evaluated by public health officials using criteria developed by states and the federal government and reported by a health department.
#
# Public health officials consider laboratory, epidemiological, clinical and vital records evidence. Tests that detect antigens or antibodies are considered evidence towards a “probable” case, but are not sufficient on their own, according to the Council of State and Territorial Epidemiologists.
#
# Confirmed Deaths
# Confirmed deaths are individuals who have died and meet the definition for a confirmed Covid-19 case. Some states reconcile these records with death certificates to remove deaths from their count where Covid-19 is not listed as the cause of death. We follow health departments in removing non-Covid-19 deaths among confirmed cases when we have information to unambiguously know the deaths were not due to Covid-19, i.e. in cases of homicide, suicide, car crash or drug overdose.
#
# “Probable” Deaths
# Probable deaths are deaths where Covid-19 is listed on the death certificate as the cause of death or a significant contributing condition, but where there has been no positive confirmatory laboratory test.
#
# Deaths among probable cases tracked by a state or local health department where a death certificate has not yet been filed may also be counted as a probable death.
#
# For more on how states count confirmed and probable deaths, see this article.
#
# Dates
# For each date, we show the cumulative number of confirmed cases and deaths as reported that day in that county or state. All cases and deaths are counted on the date they are first announced.
#
# Each date includes all cases and deaths announced that day through midnight Eastern Time. As the West Coast and Hawaii tend to release all of their new data early enough in the day.
#
# Declining Counts
# In some cases, the number of cases or deaths for a state or county will decline. This can occur when a state or county corrects an error in the number of cases or deaths they've reported in the past, or when a state moves cases from one county to another. When we are able, we will historically revise counts for all impacted dates. In other cases, this will be reflected in a single-day drop in the number of cases or deaths.
#
# Counties
# In some instances, we report data from multiple counties or other non-county geographies as a single county. For instance, we report a single value for New York City, comprising the cases for New York, Kings, Queens, Bronx and Richmond Counties. In these instances the FIPS code field will be empty. (We may assign FIPS codes to these geographies in the future.) See the list of geographic exceptions.
#
# Cities like St. Louis and Baltimore that are administered separately from an adjacent county of the same name are counted separately.
#
# “Unknown” Counties
# Many state health departments choose to report cases separately when the patient’s county of residence is unknown or pending determination. In these instances, we record the county name as “Unknown.” As more information about these cases becomes available, the cumulative number of cases in “Unknown” counties may fluctuate.
#
# Sometimes, cases are first reported in one county and then moved to another county. As a result, the cumulative number of cases may change for a given county.

# %% [markdown]
# #### Now we can call our `annotation/link_dataset_col_to_dkg` endpoint to ground each of these column names to the MIRA DKG:
# [http://100.26.10.46/#/Paper-2-annotated-vars/link_dataset_columns_to_dkg_info_annotation_link_dataset_col_to_dkg_post](http://100.26.10.46/#/Paper-2-annotated-vars/link_dataset_columns_to_dkg_info_annotation_link_dataset_col_to_dkg_post)

# %%
dct_cols_dkg = {"csv_str":col_str, "doc":col_doc, "gpt_key":GPT_KEY}
ground_res = requests.post(API_ROOT + "annotation/link_dataset_col_to_dkg/", params=dct_cols_dkg).text
print(ground_res)
# Out:
# {"date":{"col_name":"date","concept":"Date of Report","unit":"YYYY-MM-DD","description":"The date when the cases and deaths were reported.","dkg_groundings":[["apollosv:00000429","date"],["dc:date","Date"],["geonames:2130188","Hakodate"],["geonames:98182","Baghdad"],["geonames:5935277","Dartmouth"],["idocovid19:0001277","COVID-19 incidence","class"],["ido:0000480","infection incidence","class"],["idocovid19:0001283","SARS-CoV-2 incidence","class"],["hp:0001402","Hepatocellular carcinoma","class"],["oae:0000178","AE incidence rate","class"],["orphanet.ordo:409966","point prevalence","class"],["obcs:0000064","period prevalence","class"],["cemo:weighted_prevalence","weighted prevalence","class"],["idocovid19:0001272","COVID-19 prevalence","class"],["ido:0000486","infection prevalence","class"]]},"county":{"col_name":"county","concept":"County Name","unit":"Text","description":"The name of the county where the cases and deaths were reported.","dkg_groundings":[["geonames:11694038","Huocheng"],["geonames:5110302","Brooklyn"],["geonames:4297999","Lexington-Fayette"],["geonames:4299276","Louisville"],["geonames:5419384","Denver"],["geonames:1259184","Puri","individual"],["geonames:1675393","Xizhi","individual"],["geonames:6544495","Retiro","individual"],["geonames:6544104","Sants-Montjuïc","individual"],["geonames:1275701","Bijapur","individual"],["uberon:0000996","vagina","class"],["uberon:0001893","telencephalon","class"],["uberon:0000916","abdomen","class"],["go:0016020","membrane","class"],["doid:3222","causalgia","class"]]},"state":{"col_name":"state","concept":"State Name","unit":"Text","description":"The name of the state where the cases and deaths were reported.","dkg_groundings":[["geonames:2938913","Darmstadt"],["hp:0000024","Prostatitis"],["wikidata:Q61792336","united_states_survey_link"],["wikidata:Q105828635","united_states_pharmacopeia_unit"],["doid:2452","thrombophilia"],["ido:0000511","infected population","class"],["ido:0000514","susceptible population","class"],["askemo:0000001","population","class"],["obi:0000181","population","class"],["idomal:0001254","population","class"],["ncit:C133265","Non-Hospital Community Blood Bank","class"],["cemo:rate_of_community_transmission","rate of community transmission","class"],["ncit:C156646","American Health Information Community","class"],["ncit:C39326","Association of Community Cancer Centers","class"],["ncit:C177659","Veterans Affairs Community-Based Outpatient Clinic","class"]]},"fips":{"col_name":"fips","concept":"Federal Information Processing Standards Code","unit":"Numeric","description":"A unique code assigned to each county in the United States.","dkg_groundings":[["wikidata:Q917824","Federal Information Processing Standard"],["wikidata:Q1388631","FIPS"],["wikidata:Q20745899","Philipp Burger"],["wikidata:Q3063249","FIPS 10-4"],["wikidata:Q55740211","FIPS 10-4 Change Notice 1"],["wikidata:Q80184504","ICD-10 codes are a valid tool for identification of pneumonia in hospitalized patients aged > or = 65 years","class"],["wikidata:Q35039980","ICD-10 codes used to identify adverse drug events in administrative data: a systematic review","class"],["wikidata:Q48187850","ICD-10 codes detect only a proportion of all head injury admissions.","class"],["wikidata:Q53397416","ICD-10 codes: more specificity with more characters.","class"],["wikidata:Q91070090","ICD-10 coded hospitalizations due to drug hypersensitivity: A nationwide study from Chile","class"]]},"cases":{"col_name":"cases","concept":"Number of Cases","unit":"Count","description":"The cumulative number of confirmed and probable COVID-19 cases reported in the county on the given date.","dkg_groundings":[["hp:0003745","Sporadic"],["cemo:daily_cases","daily cases"],["cemo:suspected_cases","suspected cases"],["cemo:cumulative_cases","cumulative cases"],["cemo:undetected_cases","undetected cases"],["wikidata:Q28247083","Outbreaks of renal failure associated with melamine and cyanuric acid in dogs and cats in 2004 and 2007 ...

# %% [markdown]
# ## 4. Getting a Petri net (as a pyascet) from code

# %% [markdown]
# #### Let's now turn our attention to code. We have a python function that describes the Bucky dynamics:

# %%
with open("../../resources/models/Bucky/bucky.py", "r") as f:
    code = f.read()
print(code)
# Out:
# def RHS_func(self, t, y_flat, Nij, contact_mats, Aij, par, npi, aij_sparse, y):
#     # constraint on values
#     lower, upper = (0.0, 1.0)  # bounds for state vars  ## TODO multiple_value_asignment
#
#     # grab index of OOB values so we can zero derivatives (stability...)
#     too_low = y_flat <= lower
#     too_high = y_flat >= upper
#
#     # TODO we're passing in y.state just to overwrite it, we probably need another class
#     # reshape to the usual state tensor (compartment, age, node)
#     y.state = y_flat.reshape(y.state_shape)
#
#     # Clip state to be in bounds (except allocs b/c thats a counter)
#     xp.clip(y.state, a_min=lower, a_max=upper, out=y.state)
#
#     # init d(state)/dt
#     dy = buckyState(y.consts, Nij)  # TODO make a pseudo copy operator w/ zeros
#
#     # effective params after damping w/ allocated stuff
#     t_index = min(int(t), npi["r0_reduct"].shape[0] - 1)  # prevent OOB error when integrator overshoots
#     BETA_eff = npi["r0_reduct"][t_index] * par["BETA"]
#     F_eff = par["F_eff"]
#     HOSP = par["H"]
#     THETA = y.Rhn * par["THETA"]
#     GAMMA = y.Im * par["GAMMA"]
#     GAMMA_H = y.Im * par["GAMMA_H"]
#     SIGMA = y.En * par["SIGMA"]
#     SYM_FRAC = par["SYM_FRAC"]
#     # ASYM_FRAC = par["ASYM_FRAC"]
#     CASE_REPORT = par["CASE_REPORT"]
#
#     Cij = npi["contact_weights"][t_index] * contact_mats
#     Cij = xp.sum(Cij, axis=1)
#     Cij /= xp.sum(Cij, axis=2, keepdims=True)
#
#     if aij_sparse:
#         Aij_eff = Aij.multiply(npi["mobility_reduct"][t_index])
#     else:
#         Aij_eff = npi["mobility_reduct"][t_index] * Aij
#
#     # perturb Aij
#     # new_R0_fracij = truncnorm(xp, 1.0, .1, size=Aij.shape, a_min=1e-6)
#     # new_R0_fracij = xp.clip(new_R0_fracij, 1e-6, None)
#     # A = Aij * new_R0_fracij
#     # Aij_eff = A / xp.sum(A, axis=0)
#
#     # Infectivity matrix (I made this name up, idk what its really called)
#     I_tot = xp.sum(Nij * y.Itot, axis=0) - (1.0 - par["rel_inf_asym"]) * xp.sum(Nij * y.Ia, axis=0)
#
#     # I_tmp = (Aij.T @ I_tot.T).T
#     if aij_sparse:
#         I_tmp = (Aij_eff.T * I_tot.T).T
#     else:
#         I_tmp = I_tot @ Aij  # using identity (A@B).T = B.T @ A.T
#
#     beta_mat = y.S * xp.squeeze((Cij @ I_tmp.T[..., None]), axis=-1).T  ## TODO ellipsis NOT_DONE
#     ## beta_mat /= Nij  ## TODO
#     beta_mat = beta_mat / Nij
#
#     # dS/dt
#     dy.S = -BETA_eff * (beta_mat)
#     # dE/dt
#     dy.E[0] = BETA_eff * (beta_mat) - SIGMA * y.E[0]
#     dy.E[1:] = SIGMA * (y.E[:-1] - y.E[1:])
#
#     # dI/dt
#     dy.Ia[0] = (1.0 - SYM_FRAC) * SIGMA * y.E[-1] - GAMMA * y.Ia[0]
#     dy.Ia[1:] = GAMMA * (y.Ia[:-1] - y.Ia[1:])
#
#     # dIa/dt
#     dy.I[0] = SYM_FRAC * (1.0 - HOSP) * SIGMA * y.E[-1] - GAMMA * y.I[0]
#     dy.I[1:] = GAMMA * (y.I[:-1] - y.I[1:])
#
#     # dIc/dt
#     dy.Ic[0] = SYM_FRAC * HOSP * SIGMA * y.E[-1] - GAMMA_H * y.Ic[0]
#     dy.Ic[1:] = GAMMA_H * (y.Ic[:-1] - y.Ic[1:])
#
#     # dRhi/dt
#     dy.Rh[0] = GAMMA_H * y.Ic[-1] - THETA * y.Rh[0]
#     dy.Rh[1:] = THETA * (y.Rh[:-1] - y.Rh[1:])
#
#     # dR/dt
#     dy.R = GAMMA * (y.I[-1] + y.Ia[-1]) + (1.0 - F_eff) * THETA * y.Rh[-1]
#
#     # dD/dt
#     dy.D = F_eff * THETA * y.Rh[-1]
#
#     dy.incH = SYM_FRAC * CASE_REPORT * HOSP * SIGMA * y.E[-1]
#     dy.incC = SYM_FRAC * CASE_REPORT * SIGMA * y.E[-1]
#
#     # bring back to 1d for the ODE api
#     dy_flat = dy.state.ravel()
#
#     # zero derivatives for things we had to clip if they are going further out of bounds
#     dy_flat = xp.where(too_low & (dy_flat < 0.0), 0.0, dy_flat)
#     dy_flat = xp.where(too_high & (dy_flat > 0.0), 0.0, dy_flat)
#
#     return dy_flat

# %% [markdown]
# #### Using calls to the public MIT API, we can get Petri net components (places, transitions, hypothesized arcs) from this piece of code.

# %%
dict_petri = {"code": code, "gpt_key": GPT_KEY}
places = requests.post(API_ROOT + "petri/get_places", params=dict_petri).text
ast.literal_eval(places)
# Out:
# ['S', ' E', ' I', ' Ia', ' Ic', ' Rh', ' R', ' D', ' incH', ' incC']

# %%
transitions = requests.post(API_ROOT + "petri/get_transitions", params=dict_petri).text
ast.literal_eval(transitions)
# Out:
# ['BETA',
#  ' F_eff',
#  ' HOSP',
#  ' THETA',
#  ' GAMMA',
#  ' GAMMA_H',
#  ' SIGMA',
#  ' SYM_FRAC',
#  ' CASE_REPORT']

# %%
arcs = requests.post(API_ROOT + "petri/get_arcs", params=dict_petri).text
ast.literal_eval(arcs)
# Out:
# [['S', ' E'],
#  ['E', ' Ia'],
#  ['E', ' I'],
#  ['Ia', ' I'],
#  ['I', ' Ic'],
#  ['Ic', ' Rh'],
#  ['Rh', ' R'],
#  ['R', ' D'],
#  ['E', ' Rh'],
#  ['E', ' R'],
#  ['E', ' D'],
#  ['Ia', ' D'],
#  ['I', ' D'],
#  ['Ic', ' D']]

# %% [markdown]
# #### We can then convert these outputs into a py-acset (thanks to Justin Lieffers from Arizona for some of the conversion code and to Owen Lynch for the py-acset code!)

# %%
dict_acset = {"places_str": places, "transitions_str": transitions, "arcs_str": arcs}
pyacset_str = requests.post(API_ROOT + "petri/get_pyacset", params=dict_acset).text

# %%
ast.literal_eval(pyacset_str)
# Out:
# {'S': [{'sname': 'S', 'uid': 1},
#   {'sname': 'E', 'uid': 2},
#   {'sname': 'I', 'uid': 3},
#   {'sname': 'Ia', 'uid': 4},
#   {'sname': 'Ic', 'uid': 5},
#   {'sname': 'Rh', 'uid': 6},
#   {'sname': 'R', 'uid': 7},
#   {'sname': 'D', 'uid': 8},
#   {'sname': 'incH', 'uid': 9},
#   {'sname': 'incC', 'uid': 10}],
#  'T': [{'tname': 'BETA', 'uid': 11},
#   {'tname': 'F_eff', 'uid': 12},
#   {'tname': 'HOSP', 'uid': 13},
#   {'tname': 'THETA', 'uid': 14},
#   {'tname': 'GAMMA', 'uid': 15},
#   {'tname': 'GAMMA_H', 'uid': 16},
#   {'tname': 'SIGMA', 'uid': 17},
#   {'tname': 'SYM_FRAC', 'uid': 18},
#   {'tname': 'CASE_REPORT', 'uid': 19}],
#  'I': [{'it': 1, 'is': 1},
#   {'it': 2, 'is': 2},
#   {'it': 3, 'is': 2},
#   {'it': 4, 'is': 4},
#   {'it': 5, 'is': 3},
#   {'it': 6, 'is': 5},
#   {'it': 7, 'is': 6},
#   {'it': 8, 'is': 7},
#   {'it': 9, 'is': 2},
#   {'it': 10, 'is': 2},
#   {'it': 11, 'is': 2},
#   {'it': 12, 'is': 4},
#   {'it': 13, 'is': 3},
#   {'it': 14, 'is': 5}],
#  'O': [{'ot': 1, 'os': 2},
#   {'ot': 2, 'os': 4},
#   {'ot': 3, 'os': 3},
#   {'ot': 4, 'os': 3},
#   {'ot': 5, 'os': 5},
#   {'ot': 6, 'os': 6},
#   {'ot': 7, 'os': 7},
#   {'ot': 8, 'os': 8},
#   {'ot': 9, 'os': 6},
#   {'ot': 10, 'os': 7},
#   {'ot': 11, 'os': 8},
#   {'ot': 12, 'os': 8},
#   {'ot': 13, 'os': 8},
#   {'ot': 14, 'os': 8}]}

# %% [markdown]
# ## 5. MIT annotation end to end pipeline
# <a id="cellm1"></a>

# %% [markdown]
# #### Finally, we bring every annotation step together: for the original paper text, let's integrate the above extraction modules and output the MIT extraction:
# [http://100.26.10.46/#/Paper-2-annotated-vars/upload_file_annotate_annotation_upload_file_extract__post](http://100.26.10.46/#/Paper-2-annotated-vars/upload_file_annotate_annotation_upload_file_extract__post)

# %%
with open('../../resources/models/Bucky/bucky.txt', 'rb') as f:
    files = {'file': ('filename', f)}
    params = {"gpt_key": GPT_KEY}
    response = requests.post(API_ROOT + "annotation/upload_file_extract/",  params=params,  files=files)
    json_str = response.text
print(json_str)
# Out:
# {"attributes":[{"type":"anchored_extraction","amr_element_id":null,"payload":{"id":{"id":"v0"},"names":[{"id":{"id":"v0"},"name":"S_ij","extraction_source":null,"provenance":{"method":"MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)","timestamp":"2023-07-07T21:57:34.463911"}}],"descriptions":[{"id":{"id":"v0"},"source":" Proportion of individuals who are susceptible to the virus","grounding":null,"extraction_source":null,"provenance":{"method":"MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)","timestamp":"2023-07-07T21:57:34.463911"}},{"id":{"id":"v0"},"source":" Proportion of individuals whoI^{\text {asym }}","grounding":null,"extraction_source":null,"provenance":{"method":"MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)","timestamp":"2023-07-07T21:57:34.463911"}}],"value_specs":null,"groundings":[{"grounding_text":"Sanxia","grounding_id":"geonames:1670106","source":[],"score":1.0,"provenance":{"method":"MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)","timestamp":"2023-07-07T21:57:34.463911"}},{"grounding_text":"Shijiazhuang","grounding_id":"geonames:1795270","source":[],"score":1.0,"provenance":{"method":"MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)","timestamp":"2023-07-07T21:57:34.463911"}}],"data_columns":[]}},{"type":"anchored_extraction","amr_element_id":null,"payload":{"id":{"id":"v1"},"names":[{"id":{"id":"v1"},"name":"E_ij","extraction_source":null,"provenance":{"method":"MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)","timestamp":"2023-07-07T21:57:34.463911"}}],"descriptions":[{"id":{"id":"v1"},"source":" Proportion of individuals who have been exposed to the virus","grounding":null,"extraction_source":null,"provenance":{"method":"MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)","timestamp":"2023-07-07T21:57:34.463911"}}],"value_specs":null,"groundings":[{"grounding_text":"Beijing","grounding_id":"geonames:1816670","source":[],"score":1.0,"provenance":{"method":"MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)","timestamp":"2023-07-07T21:57:34.463911"}},{"grounding_text":"Beijing","grounding_id":"geonames:2038349","source":[],"score":1.0,"provenance":{"method":"MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)","timestamp":"2023-07-07T21:57:34.463911"}}],"data_columns":[{"id":{"id":"5-2"},"name":"new_confirmed_age_0","dataset":{"id":{"id":"5"},"name":"usa-cases-hospitalized-by-age.csv","metadata":"https://github.com/DARPA-ASKEM/program-milestones/blob/main/6-month-milestone/evaluation/scenario_3/ta_1/google-health-data/usa-cases-hospitalized-by-age.csv"}},{"id":{"id":"5-3"},"name":"new_confirmed_age_1","dataset":{"id":{"id":"5"},"name":"usa-cases-hospitalized-by-age.csv","metadata":"https://github.com/DARPA-ASKEM/program-milestones/blob/main/6-month-milestone/evaluation/scenario_3/ta_1/google-health-data/usa-cases-hospitalized-by-age.csv"}}]}},{"type":"anchored_extraction","amr_element_id":null,"payload":{"id":{"id":"v2"},"names":[{"id":{"id":"v2"},"name":"I_ij^hosp","extraction_source":null,"provenance":{"method":"MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)","timestamp":"2023-07-07T21:57:34.463911"}}],"descriptions":[{"id":{"id":"v2"},"source":" Proportion of individuals that are exhibiting severe disease symptoms and are in need of hospitalization","grounding":null,"extraction_source":null,"provenance":{"method":"MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)","timestamp":"2023-07-07T21:57:34.463911"}}],"value_specs":null,"groundings":[],"data_columns":[{"id":{"id":"6-2"},"name":"new_hospitalized_patients","dataset":{"id":{"id":"6"},"name":"usa-hospitalizations.csv","metadata":"https://github.com/DARPA-ASKEM/program-milestones/blob/main/6-month-milestone/evaluation/scenario_3/ta_1/google-health-data/usa-hospitalizations.csv"}},{"id":{"id ...

# %% [markdown]
# ## 6. Interacting with the University of Arizona extraction
# <a id="cellm2"></a>

# %% [markdown]
# #### With both the University of Arizona and MIT extractions, we first build the entity matching mapping for all the extracted variable entities, and then integrate the two integration together with the unified TA1 data model.
# [http://100.26.10.46/#/TA1-Integration/upload_files_integration_integration_get_mapping_post](http://100.26.10.46/#/TA1-Integration/upload_files_integration_integration_get_mapping_post)

# %%
with open('m_temp.json', 'rb') as f_mit, open('a_temp.json', 'rb') as f_arizona:
    files = { 'mit_file': ('bucky__mit-extraction_id.json', f_mit, 'application/json'),
        'arizona_file': ('bucky_arizona_output_example.json', f_arizona, 'application/json')}
    params = {"gpt_key": GPT_KEY}
    response = requests.post(API_ROOT + "integration/get_mapping", params=params, files=files)
    print(response.text)
# Out:
# {"attributes":[{"type":"anchored_extraction","amr_element_id":null,"payload":{"id":{"id":"R:190348269"},"names":[{"id":{"id":"T:-1709799622"},"name":"Bucky","extraction_source":{"page":0,"block":0,"char_start":738,"char_end":743,"document_reference":{"id":"buckymodel_webdocs.pdf"}},"provenance":{"method":"Skema TR Pipeline rules","timestamp":"2023-07-07T16:46:30.076416"}}],"descriptions":[{"id":{"id":"T:-486841659"},"source":"time","grounding":[{"grounding_text":"time since time scale zero","grounding_id":"apollosv:00000272","source":[],"score":0.8945620059967041,"provenance":{"method":"SKEMA-TR-Embedding","timestamp":"2023-07-07T16:46:30.077120"}}],"extraction_source":{"page":0,"block":0,"char_start":732,"char_end":736,"document_reference":{"id":"buckymodel_webdocs.pdf"}},"provenance":{"method":"Skema TR Pipeline rules","timestamp":"2023-07-07T16:46:30.076416"}}],"value_specs":[],"groundings":[],"data_columns":null}},{"type":"anchored_extraction","amr_element_id":null,"payload":{"id":{"id":"R:159895595"},"names":[{"id":{"id":"T:2131207786"},"name":"SEIR","extraction_source":{"page":0,"block":0,"char_start":56,"char_end":60,"document_reference":{"id":"buckymodel_webdocs.pdf"}},"provenance":{"method":"Skema TR Pipeline rules","timestamp":"2023-07-07T16:46:30.077206"}}],"descriptions":[{"id":{"id":"T:-1520869470"},"source":"spatially distributed","grounding":[],"extraction_source":{"page":0,"block":0,"char_start":34,"char_end":55,"document_reference":{"id":"buckymodel_webdocs.pdf"}},"provenance":{"method":"Skema TR Pipeline rules","timestamp":"2023-07-07T16:46:30.077206"}}],"value_specs":[],"groundings":[],"data_columns":null}},{"type":"anchored_extraction","amr_element_id":null,"payload":{"id":{"id":"E:-337831219"},"names":[{"id":{"id":"T:1326919589"},"name":"S","extraction_source":{"page":0,"block":0,"char_start":562,"char_end":563,"document_reference":{"id":"buckymodel_webdocs.pdf"}},"provenance":{"method":"Skema TR Pipeline rules","timestamp":"2023-07-07T16:46:30.077278"}},{"id":{"id":"v0"},"name":"S_i j","extraction_source":null,"provenance":{"method":"MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)","timestamp":"2023-07-07T16:46:30.127525"}}],"descriptions":[{"id":{"id":"T:1687413640"},"source":"fraction of the population","grounding":[{"grounding_text":"count of simulated population","grounding_id":"apollosv:00000022","source":[],"score":0.8330355286598206,"provenance":{"method":"SKEMA-TR-Embedding","timestamp":"2023-07-07T16:46:30.077313"}}],"extraction_source":{"page":0,"block":0,"char_start":570,"char_end":596,"document_reference":{"id":"buckymodel_webdocs.pdf"}},"provenance":{"method":"Skema TR Pipeline rules","timestamp":"2023-07-07T16:46:30.077278"}},{"id":{"id":"v0"},"source":" Proportion of individuals who are susceptible to the virus","grounding":null,"extraction_source":null,"provenance":{"method":"MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)","timestamp":"2023-07-07T16:46:30.127525"}}],"value_specs":[],"groundings":[{"grounding_text":"Meruvax I","grounding_id":"vo:0003109","source":[],"score":0.7847759127616882,"provenance":{"method":"SKEMA-TR-Embedding","timestamp":"2023-07-07T16:46:30.077291"}},{"grounding_text":"Skikda","grounding_id":"geonames:2479536","source":[],"score":1.0,"provenance":{"method":"MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)","timestamp":"2023-07-07T16:46:30.127525"}},{"grounding_text":"Sterlitamak","grounding_id":"geonames:487495","source":[],"score":1.0,"provenance":{"method":"MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)","timestamp":"2023-07-07T16:46:30.127525"}}],"data_columns":null}},{"type":"anchored_extraction","amr_element_id":null,"payload":{"id":{"id":"E:-1921441554"},"names":[{"id":{"id":"T:-24678027"},"name":"asym frac","extraction_source":{"page":0,"block":0,"char_start":142,"char_end":151,"document_reference":{"id":"buckymodel_webdocs.pdf"}},"provenance":{"method":"Sk ...
